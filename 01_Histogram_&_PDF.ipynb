# %% [markdown]
# # **Histogram and Probability Density Functions**

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal
from scipy.stats import norm
import seaborn as sns

# %%
sample = normal(loc=50, scale=5,size=1000)
sample.mean()
# Out:
# np.float64(49.9610205775058)

# %%
# plot histogram to understand the distribution of data
plt.hist(sample,bins=10)
# Out:
# (array([  2.,   6.,  32.,  99., 216., 300., 205., 100.,  33.,   7.]),
#  array([31.17435824, 34.598095  , 38.02183177, 41.44556854, 44.8693053 ,
#         48.29304207, 51.71677883, 55.1405156 , 58.56425237, 61.98798913,
#         65.4117259 ]),
#  <BarContainer object of 10 artists>)

# %%
# calculate sample mean and sample std dev
sample_mean = sample.mean()
sample_std = sample.std()

# %%
# fit the distribution with the above parameters
dist = norm(60, 12)

# %%
values = np.linspace(sample.min(),sample.max(),100)

# %%
probabilities = [dist.pdf(value) for value in values]

# %%
# plot the histogram and pdf
plt.hist(sample,bins=10,density=True)
plt.plot(values,probabilities)

# %%
sns.displot(sample)
